# %%
# %pip install pandas, -q
# %pip install openpyxl -q
import pandas as pd
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: 'pandas,'
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
histo1 = pd.read_excel("data/Histo vente PMI 1er semestre 2024.xlsx")
histo2 = pd.read_excel("data/Histo vente PMI 2eme semestre 2024.xlsx")

# %%
histo1.head()
# Out:
#              Etablissement        Grde Fam         Fam Sous Fam  \
# 0  Prince Medical Industry   Gynécologique  Inserteurs      NaN
# 1  Prince Medical Industry   Gynécologique  Inserteurs      NaN
# 2  Prince Medical Industry   Gynécologique  Inserteurs      NaN
# 3  Prince Medical Industry  Sous traitance   Tubes PFM      NaN
# 4  Prince Medical Industry  Sous traitance   Tubes PFM      NaN
#
#                Abrégé  Référence  Cmde  Ligne  Ligne soldée       Code  ...  \
# 0  Prince Medical SAS        NaN  1761      1         False      NT380  ...
# 1  Prince Medical SAS        NaN  1761      2         False      NT380  ...
# 2  Prince Medical SAS        NaN  1761      3         False      NT380  ...
# 3  Prince Medical SAS        NaN  1865      2         False  MN1820000  ...
# 4  Prince Medical SAS        NaN  2095      1         False  MN1820000  ...
#
#               Créé le Livraison souhaitée  A livrer le Etat livraison  \
# ...

# %%
histo2.head()
# Out:
#              Etablissement        Grde Fam         Fam Sous Fam  \
# 0  Prince Medical Industry   Gynécologique  Inserteurs      NaN
# 1  Prince Medical Industry   Gynécologique  Inserteurs      NaN
# 2  Prince Medical Industry   Gynécologique  Inserteurs      NaN
# 3  Prince Medical Industry  Sous traitance   Tubes PFM      NaN
# 4  Prince Medical Industry  Sous traitance   Tubes PFM      NaN
#
#                Abrégé  Référence  Cmde  Ligne  Ligne soldée       Code  ...  \
# 0  Prince Medical SAS        NaN  1761      1         False      NT380  ...
# 1  Prince Medical SAS        NaN  1761      2         False      NT380  ...
# 2  Prince Medical SAS        NaN  1761      3         False      NT380  ...
# 3  Prince Medical SAS        NaN  1865      2         False  MN1820000  ...
# 4  Prince Medical SAS        NaN  2095      1         False  MN1820000  ...
#
#               Créé le Livraison souhaitée  A livrer le Etat livraison  \
# ...

# %%
columns_1 = set(histo1.columns)
columns_2 = set(histo2.columns)
only_in_histo1 = columns_1 - columns_2
only_in_histo2 = columns_2 - columns_1

# %%
only_in_histo1, only_in_histo2
# Out:
# (set(), set())

# %%
histo= pd.concat([histo1, histo2], ignore_index=True)

# %%
histo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Etablissement           400 non-null    object
#  1   Grde Fam                398 non-null    object
#  2   Fam                     396 non-null    object
#  3   Sous Fam                282 non-null    object
#  4   Abrégé                  400 non-null    object
#  5   Référence               0 non-null      float64
#  6   Cmde                    400 non-null    int64
#  7   Ligne                   400 non-null    int64
#  8   Ligne soldée            400 non-null    bool
#  9   Code                    400 non-null    object
#  10  Réf rég                 388 non-null    object
#  11  Désignation             400 non-null    object
#  12  Qtte cmdée              400 non-null    int64
#  13  Créé le                 400 non-null    datetime64[ns]
# ...

# %%
histo.to_excel("data/Histo vente PMI 2024.xlsx", index=False)

# %%
df_hist = pd.read_excel('data/Histo vente PMI 2021 au 2023.xlsx')
df_2024 = pd.read_excel('data/Histo vente PMI 2024.xlsx')

# Print column names
print("2021–2023 Columns:", df_hist.columns.tolist())
print("2024 Columns:", df_2024.columns.tolist())
# Out:
# 2021–2023 Columns: ['Commande', 'Cmde Date', 'Saisi le', 'Saisi par', 'Famille', 'Reference', 'Designation', 'Date confirmée', 'Qtte Cmdée', 'Qtte Envoi Cumulée', 'Qtte Envoi à Temps', 'Reste à livrer', 'Avancement Cmde', 'Taux de service', 'AvancementGlobalCommande', 'LigneCMDE_Bloque', 'LigneCMDE_Prix_U']
# 2024 Columns: ['Etablissement', 'Grde Fam', 'Fam', 'Sous Fam', 'Abrégé', 'Référence', 'Cmde', 'Ligne', 'Ligne soldée', 'Code', 'Réf rég', 'Désignation', 'Qtte cmdée', 'Créé le', 'Livraison souhaitée', 'A livrer le', 'Etat livraison', 'Total Livrée', 'Reste A Livrer', 'Dernière Livraison', 'Avancement', 'OTD Rate', 'Responsable production']
